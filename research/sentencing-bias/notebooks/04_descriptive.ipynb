# %% [markdown]
# # 04 - Descriptive Analysis
#
# **Purpose:** Summary statistics and exploratory visualizations for the full dataset.
#
# | | |
# |---|---|
# | **Inputs** | `data/processed/sentencing_clean.parquet` |
# | **Outputs** | `tables/`, `figures/` |
# | **Runtime** | ~1 minute (estimated) |
#
# ## Steps
# 1. Sample characteristics
# 2. Demographic distributions
# 3. Sentencing distributions
# 4. Bivariate relationships
# 5. Create descriptive tables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## 1. Load Clean Data

# %%
# df = pd.read_parquet('../data/processed/sentencing_clean.parquet')

# %% [markdown]
# ## 2. Sample Characteristics
#
# N cases by year, court, crime category

# %%
# TODO: Table 1 - Sample characteristics

# %% [markdown]
# ## 3. Demographic Distributions

# %%
# TODO: Gender, age, education, employment distributions

# %% [markdown]
# ## 4. Sentencing Distributions

# %%
# TODO: Sentence type breakdown, severity distribution

# %% [markdown]
# ## 5. Bivariate Relationships

# %%
# TODO: Mean severity by gender (t-test)
# TODO: Mean severity by education (ANOVA)
# TODO: Severity vs age (scatter + LOESS)
