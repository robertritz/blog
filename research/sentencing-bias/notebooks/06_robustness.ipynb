# %% [markdown]
# # 06 - Robustness Checks
#
# **Purpose:** Test sensitivity of results to alternative specifications.
#
# | | |
# |---|---|
# | **Inputs** | `data/processed/sentencing_clean.parquet` |
# | **Outputs** | Robustness tables, comparison figures |
# | **Runtime** | ~10 minutes (estimated) |
#
# ## Checks
# 1. Alternative DV specifications
# 2. Alternative model specifications
# 3. Sensitivity to outliers
# 4. Temporal stability
# 5. Subgroup analyses

# %%
import sys
sys.path.insert(0, '../src')

import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

from severity_scale import sensitivity_analysis

# %% [markdown]
# ## 1. Alternative DV Specifications

# %%
# TODO: Imprisonment months only
# TODO: Binary incarceration
# TODO: Alternative severity weights

# %% [markdown]
# ## 2. Alternative Model Specifications

# %%
# TODO: No court FE
# TODO: Crime article FE instead of category
# TODO: Gender × crime interaction

# %% [markdown]
# ## 3. Sensitivity to Outliers

# %%
# TODO: Exclude top/bottom 1%
# TODO: Exclude imputed cases

# %% [markdown]
# ## 4. Temporal Stability

# %%
# TODO: Pre/post 2017 comparison
# TODO: Rolling window analysis

# %% [markdown]
# ## 5. Subgroup Analyses

# %%
# TODO: By crime category
# TODO: Ulaanbaatar vs aimag courts

# %% [markdown]
# ## 6. Summary of Robustness

# %%
# TODO: Table summarizing coefficient stability across specifications
