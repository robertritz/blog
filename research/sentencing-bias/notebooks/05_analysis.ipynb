# %% [markdown]
# # 05 - Main Analysis
#
# **Purpose:** Regression analysis testing H1-H4 (gender, education, age, employment effects on sentencing).
#
# | | |
# |---|---|
# | **Inputs** | `data/processed/sentencing_clean.parquet` |
# | **Outputs** | Regression tables, coefficient plots |
# | **Runtime** | ~5 minutes (estimated) |
#
# ## Models
# 1. OLS with robust standard errors (primary)
# 2. Multilevel model with court/judge random effects
# 3. Two-stage selection model

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats

# %% [markdown]
# ## 1. Load Data and Prepare Variables

# %%
# df = pd.read_parquet('../data/processed/sentencing_clean.parquet')

# Create dummy variables, age^2, etc.

# %% [markdown]
# ## 2. Primary Model: OLS with Robust SE
#
# ```
# severity ~ gender + age + age² + education + employed +
#            crime_category + prior_criminal +
#            aggravating_count + mitigating_count +
#            year_FE + court_FE
# ```

# %%
# TODO: Run primary OLS model
# model = smf.ols(formula, data=df).fit(cov_type='HC3')

# %% [markdown]
# ## 3. Multilevel Model

# %%
# TODO: Mixed effects model with court random intercept
# model_mixed = smf.mixedlm(formula, data=df, groups='court_id').fit()

# %% [markdown]
# ## 4. Two-Stage Selection Model

# %%
# Stage 1: P(imprisonment)
# Stage 2: Sentence length | imprisoned

# %% [markdown]
# ## 5. Results Summary Table

# %%
# TODO: Create publication-ready regression table
